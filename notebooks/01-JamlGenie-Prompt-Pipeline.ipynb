# %% [markdown]
# ## Step 3: Sensibility Check
#
# Calls the actual `McpServer.RefineStep3_SensibilityCheck()` method

# %%
var step3Output = mcpServer.RefineStep3_SensibilityCheck(step2Output);
Console.WriteLine($"After Step 3 (Sensibility): {step3Output}");

# %%
// Get ALL steps at once - this is the method the backend actually uses
var (finalPrompt, allSteps) = mcpServer.RefinePromptWithSteps(userPrompt);

Console.WriteLine("=".PadRight(60, '='));
Console.WriteLine("PROMPT PIPELINE SUMMARY");
Console.WriteLine("=".PadRight(60, '='));
Console.WriteLine($"Original:     {allSteps.Original}");
Console.WriteLine($"Step 1:       {allSteps.AfterStep1}");
Console.WriteLine($"Step 2:       {allSteps.AfterStep2}");
Console.WriteLine($"Step 3:       {allSteps.AfterStep3}");
Console.WriteLine($"Final (AI):   {allSteps.Final}");
Console.WriteLine("=".PadRight(60, '='));
